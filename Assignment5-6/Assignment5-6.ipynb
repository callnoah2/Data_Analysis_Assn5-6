# %% [markdown]
# # Assignments 5 & 6

# %% [markdown]
# ## Assignment 5

# %% [markdown]
# ### 1

# %% [markdown]
# ### a
#
# I made this graph in Adobe Illustrator.
# I started by making the graph, and labeling the axis.
# Then I put a point for each of the values.
# Then I Identified outliers.
# Then I identified the max and min values.
# Then I boxed teh innerquartile range.
# And finally I drew the median.
# See boxplot as ManualPlot.png

# %% [markdown]
# ### B

# %%
import matplotlib.pyplot as plt

# Define the data array
data = [-1, 3, 7, 8, -15, 7, 2, 1, 25]

# Create a boxplot
plt.boxplot(data)

# Add labels and title
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Boxplot of the Data')

# Show the plot
plt.show()

# %% [markdown]
# ### B Cont.
#
# Yes, the plots are roughly the same, the midline on the boxplot by python is a bit lower than mine.
